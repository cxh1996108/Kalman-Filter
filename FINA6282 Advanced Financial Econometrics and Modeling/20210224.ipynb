# %%
import numpy as np
from numpy.random import random as rnd 
import pandas as pd
from numpy.linalg import inv as ii

class parameters:
    def __init__(self,n):
        self.mu = rnd((n,1))
        self.F = rnd((n,n))
        self.R = rnd((1,1))
        self.q = rnd((n,n))
        self.Q = self.q.T@self.q
        self.beta00 = rnd((n,1))
        self.p00 = rnd((n,n))
        self.P00 = self.p00.T@self.p00

class data:
    def __init__(self,n):
        self.y = rnd((1,1))
        self.x = rnd((1,n))
        
class prediction:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.eta = rnd((1,1))
        self.f = rnd((1,1))
        
class updating:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.K = rnd((n,1))
        
class a_period:
    def __init__(self,t,model):
        self.t = t
        self.mymodel = model
        n = self.mymodel.n
        self.data = data(n)
        self.prd = prediction(n)
        self.upd = updating(n)
    def predict(self):
        par = self.mymodel.pars
        mu = par.mu
        F = par.F
        if self.t == 0: 
            b = par.beta00
            P = par.P00
        else:
            previous_period = self.mymodel.sample[self.t-1]
            b = previous_period.upd.beta
            P = previous_period.upd.P
        self.prd.beta = mu + F @ b
        self.prd.P = (F @ P) @ F.T + par.Q
        x = self.data.x
        self.prd.eta = self.data.y - x @ self.prd.beta
        self.prd.f = (x @ self.prd.P) @ x.T + par.R
    def update(self):
        P = self.prd.P
        x = self.data.x
        K = (P @ x.T) @ ii(self.prd.f)
        self.upd.K = K
        self.upd.beta = self.prd.beta + K @ self.prd.eta
        self.upd.P = P - (K @ x) @ P
            
class the_model:
    def __init__(self,datafile):
        self.datafile = datafile
        df = pd.read_csv(datafile)
        T,n = df.shape
        n = n - 1
        self.n = n
        self.T = T
        self.pars = parameters(n)
        self.sample = []
        for t in range(T): 
            new_period = a_period(t,self)
            new_period.data.y = np.array([[ df.iloc[t,0] ]])
            new_period.data.x = df.iloc[t,1:].values.reshape((1,n))
            self.sample.append(new_period)
    def run(self):
        for t in range(self.T):
            self.sample[t].predict()
            self.sample[t].update()

# %%
ibm = the_model("IBM.csv")

# %%
ibm.run()

# %%
for aperiod in ibm.sample: print(aperiod.upd.beta.T)
# Out:
# [[0.75746452 1.00740751 0.86714058]]
# [[1.42770917 2.26842493 1.52754914]]
# [[2.29930609 3.29558536 1.91494411]]
# [[3.98198873 5.22369849 2.79657962]]
# [[6.19159403 7.78365993 3.94873809]]
# [[4.71639188 6.05031192 3.16035964]]
# [[6.81441487 8.4977946  4.27749287]]
# [[4.94836932 6.32163734 3.28102226]]
# [[5.13632677 6.55607217 3.39766615]]
# [[6.91546954 8.61604388 4.32855947]]
# [[5.59382995 7.07893589 3.6324501 ]]
# [[ 8.70458367 10.67666063  5.2566303 ]]
# [[0.42904563 1.11471092 0.93967694]]
# [[0.79358219 1.50956023 1.10476386]]
# [[1.91686011 2.83881613 1.72807484]]
# [[3.50757503 4.68793112 2.55691832]]
# [[4.45008095 5.75950684 3.03454788]]
# [[5.19268482 6.62209155 3.42823341]]
# [[7.6288905  9.4317998  4.69378551]]
# [[11.17952558 13.5314666   6.54129053]]
# [[3.45288236 4.61908494 2.52603028]]
# [[1.1959878  2.00856906 1.34474596]]
# [[2.4979002  3.51789364 2.02946652]]
# [[4.0439458  5.30265991 2.83344661]]
# [[1.47167676 2.33172316 1.49150072]]
# [[3.0947225  4.2060646  2.33929195]]
# [[0.41081111 1.10827554 0.94059779]]
# [[1.43143241 2.2885103  1.47483251]]
# [[2.96116804 4.05298373 2.2701263 ]]
# [[1.49675983 2.3569245  1.50425384]]
# [[2.93545743 4.02387961 2.25743049]]
# [[3.15009822 4.26902684 2.36542972]]
# [[2.7593518  3.81885024 2.15922131]]
# [[1.02411607 1.80339958 1.25087583]]
# [[2.18749166 3.15880437 1.86844635]]
# [[3.85927011 5.08967058 2.7373423 ]]
# [[4.79293648 6.16329831 3.22051222]]
# [[2.2175486  3.19027238 1.87869655]]
# [[3.97873338 5.22614519 2.79915095]]
# [[5.97692689 7.53153559 3.83783706]]
# [[-0.13741268  0.47373745  0.65308721]]
# [[0.6321351  1.36572245 1.05913182]]
# [[1.02193198 1.81526287 1.25971799]]
# [[0.93038566 1.70742136 1.21210369]]
# [[1.99348575 2.93791366 1.76715664]]
# [[2.76363235 3.82332798 2.16596945]]
# [[4.00641101 5.25802245 2.81377859]]
# [[6.68377176 8.34748762 4.20550752]]
# [[ 9.97848824 12.14728537  5.91810928]]
# [[2.79533451 3.86106751 2.18243276]]
# [[2.71625393 3.76910426 2.14009615]]
# [[3.01298443 4.10918347 2.29473525]]
# [[4.33133005 5.63352986 2.98218361]]
# [[7.23098777 8.97776642 4.48922963]]
# [[ 8.26510305 10.16968819  5.02657263]]
# [[10.80489304 13.10126242  6.34856369]]
# [[3.73812243 4.94840759 2.67295084]]
# [[3.01898836 4.11855191 2.29894461]]
# [[-0.48281554  0.07502054  0.47408504]]
# [[-0.19167942  0.41214669  0.62834577]]
# [[0.58004483 1.30480126 1.03077086]]
# [[1.65816187 2.55126706 1.59305585]]
# [[1.09180506 1.8966337  1.29695133]]
# [[2.29474351 3.2847019  1.92332237]]
# [[2.81314538 3.88559118 2.19331638]]
# [[2.26606142 3.24904161 1.90568168]]
# [[3.94105912 5.18322379 2.779536  ]]
# [[2.52400712 3.5493992  2.04260633]]
# [[3.08069578 4.1895631  2.32977006]]
# [[1.55615617 2.43120077 1.53743166]]
# [[2.20837848 3.17369161 1.86962147]]
# [[1.59257643 2.4576428  1.54355582]]
# [[2.24431577 3.22671209 1.89852864]]

# %% [markdown]
# $\mathcal{L} = -\frac{1}{2}\sum_{t-1}^T \Big(\ln(2\pi f_{t|t-1}) + \eta'_{t|t-1}f^{-1}_{t|t-1}\eta_{t|t-1}\Big).$

# %%
#self.ll = math.log(2 * math.pi * f) + (eta.T @ inv(f)) @ eta

# %%
import numpy as np
from numpy.random import random as rnd 
import pandas as pd
from numpy.linalg import inv
import math

class parameters:
    def __init__(self,n):
        self.mu = rnd((n,1))
        self.F = rnd((n,n))
        self.R = rnd((1,1))
        self.q = rnd((n,n))
        self.Q = self.q.T@self.q
        self.beta00 = rnd((n,1))
        self.p00 = rnd((n,n))
        self.P00 = self.p00.T@self.p00

class data:
    def __init__(self,n):
        self.y = rnd((1,1))
        self.x = rnd((1,n))
        
class prediction:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.eta = rnd((1,1))
        self.f = rnd((1,1))
        
class updating:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.K = rnd((n,1))
        
class a_period:
    def __init__(self,t,model):
        self.t = t
        self.mymodel = model
        n = self.mymodel.n
        self.data = data(n)
        self.prd = prediction(n)
        self.upd = updating(n)
    def predict(self):
        par = self.mymodel.pars
        mu = par.mu
        F = par.F
        if self.t == 0: 
            b = par.beta00
            P = par.P00
        else:
            previous_period = self.mymodel.sample[self.t-1]
            b = previous_period.upd.beta
            P = previous_period.upd.P
        self.prd.beta = mu + F @ b
        self.prd.P = (F @ P) @ F.T + par.Q
        x = self.data.x
        eta = self.data.y - x @ self.prd.beta
        f = (x @ self.prd.P) @ x.T + par.R
        self.prd.eta = eta
        self.prd.f = f
        self.ll = float( math.log(2 * math.pi * f) + (eta.T @ inv(f)) @ eta )
        
    def update(self):
        P = self.prd.P
        x = self.data.x
        K = (P @ x.T) @ ii(self.prd.f)
        self.upd.K = K
        self.upd.beta = self.prd.beta + K @ self.prd.eta
        self.upd.P = P - (K @ x) @ P
            
class the_model:
    def __init__(self,datafile):
        self.datafile = datafile
        df = pd.read_csv(datafile)
        T,n = df.shape
        n = n - 1
        self.n = n
        self.T = T
        self.pars = parameters(n)
        self.sample = []
        for t in range(T): 
            new_period = a_period(t,self)
            new_period.data.y = np.array([[ df.iloc[t,0] ]])
            new_period.data.x = df.iloc[t,1:].values.reshape((1,n))
            self.sample.append(new_period)
    def run(self):
        self.ll = 0
        for t in range(self.T):
            period_t = self.sample[t]
            period_t.predict()
            period_t.update()
            self.ll = self.ll + period_t.ll
        self.ll = -0.5 * self.ll

# %%
ibm = the_model("IBM.csv")

# %%
ibm.run()

# %%
ibm.ll
# Out:
# -548.0804221525112

# %%
for aperiod in ibm.sample: print(aperiod.upd.beta.T)
# Out:
# [[1.35379248 0.44646624 1.38415563]]
# [[2.7486898  2.29068601 2.7718455 ]]
# [[4.64741265 4.1296778  4.15988187]]
# [[8.60845482 7.67408013 7.29951405]]
# [[11.14827401 10.04745313  9.39200879]]
# [[5.87095283 5.16528888 5.1523433 ]]
# [[8.98788875 8.06370567 7.64377752]]
# [[3.12892034 2.58778005 2.92465159]]
# [[2.95734805 2.43165966 2.79022562]]
# [[6.20249045 5.45800614 5.40231018]]
# [[4.58293394 3.94638572 4.09794958]]
# [[8.40270838 7.50871067 7.17491664]]
# [[0.68899782 0.31654524 0.96150345]]
# [[1.06397861 0.66455852 1.26429112]]
# [[2.58893291 2.08877756 2.49207083]]
# [[5.10904744 4.43746971 4.52129667]]
# [[4.2293337  3.61701585 3.8132594 ]]
# [[4.36595196 3.74501075 3.92359018]]
# [[7.58955859 6.75001466 6.519586  ]]
# [[7.18960854 6.37769399 6.19763193]]
# [[4.88082747 4.22472949 4.33778751]]
# [[2.99515685 2.46638373 2.81886657]]
#
# <font face = "Georgia" size="+1">To maximize this funcion, we are going to use the <tt>scipy</tt>'s <tt> minimize</tt> function to minimize the <strong>negative</strong> value of the <tt>self.ll</tt>.</font>

# %%
from scipy.optimize import minimize

minimize(
    fun = # The function that we would like to minimize;
    x0 = # Starting values of the parameters;
    method = # The numerical method to be used for minimization;
    constraints = # Define the valid sets of the values of the parameters;
    tol = # Tolerance for convergense;
    options = # Options for the minimization process; e.g., the maximum number of 
              # iterations to be attempted.
)

# %%
import numpy as np
from numpy.random import random as rnd 
import pandas as pd
from numpy.linalg import inv
import math

class parameters:
    def __init__(self,n):
        self.mu = rnd((n,1))
        self.F = rnd((n,n))
        self.R = rnd((1,1))
        self.q = rnd((n,n))
        self.Q = self.q.T@self.q
        self.beta00 = rnd((n,1))
        self.p00 = rnd((n,n))
        self.P00 = self.p00.T@self.p00
        self.parnames = list(self.__dict__.keys())
        self.parnames.sort()
        self.do_not_pack = ['Q','P00']
    def pack (self):
        big_column = np.array([[]]).T
        for aname in self.parnames: 
            if aname in self.do_not_pack: continue
            matrix = getattr(ibm.pars,aname) 
            matrix = matrix.reshape((-1,1),order = "F") 
            big_column = np.concatenate((big_column,matrix),axis = 0)
        return big_column
            
class data:
    def __init__(self,n):
        self.y = rnd((1,1))
        self.x = rnd((1,n))
        
class prediction:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.eta = rnd((1,1))
        self.f = rnd((1,1))
        
class updating:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.K = rnd((n,1))
        
class a_period:
    def __init__(self,t,model):
        self.t = t
        self.mymodel = model
        n = self.mymodel.n
        self.data = data(n)
        self.prd = prediction(n)
        self.upd = updating(n)
    def predict(self):
        par = self.mymodel.pars
        mu = par.mu
        F = par.F
        if self.t == 0: 
            b = par.beta00
            P = par.P00
        else:
            previous_period = self.mymodel.sample[self.t-1]
            b = previous_period.upd.beta
            P = previous_period.upd.P
        self.prd.beta = mu + F @ b
        self.prd.P = (F @ P) @ F.T + par.Q
        x = self.data.x
        eta = self.data.y - x @ self.prd.beta
        f = (x @ self.prd.P) @ x.T + par.R
        self.prd.eta = eta
        self.prd.f = f
        self.ll = float( math.log(2 * math.pi * f) + (eta.T @ inv(f)) @ eta )
        
    def update(self):
        P = self.prd.P
        x = self.data.x
        K = (P @ x.T) @ ii(self.prd.f)
        self.upd.K = K
        self.upd.beta = self.prd.beta + K @ self.prd.eta
        self.upd.P = P - (K @ x) @ P
            
class the_model:
    def __init__(self,datafile):
        self.datafile = datafile
        df = pd.read_csv(datafile)
        T,n = df.shape
        n = n - 1
        self.n = n
        self.T = T
        self.pars = parameters(n)
        self.sample = []
        for t in range(T): 
            new_period = a_period(t,self)
            new_period.data.y = np.array([[ df.iloc[t,0] ]])
            new_period.data.x = df.iloc[t,1:].values.reshape((1,n))
            self.sample.append(new_period)
    def run(self):
        self.ll = 0
        for t in range(self.T):
            period_t = self.sample[t]
            period_t.predict()
            period_t.update()
            self.ll = self.ll + period_t.ll
        self.ll = -0.5 * self.ll

# %%
ibm = the_model('IBM.csv')

# %%
ibm.pars.pack()
# Out:
# array([[0.30694643],
#        [0.93702452],
#        [0.53656699],
#        [0.02323843],
#        [0.27746739],
#        [0.49101502],
#        [0.86633124],
#        [0.98659775],
#        [0.93083993],
#        [0.49647692],
#        [0.32641551],
#        [0.48217113],
#        [0.64233266],
#        [0.59422904],
#        [0.83884237],
#        [0.81291675],
#        [0.34668714],
#        [0.59471478],
#        [0.04274704],
#        [0.26985976],
#        [0.86019759],
#        [0.11229545],
#        [0.41224117],
#        [0.32167221],
#        [0.25471399],
#        [0.41412691],
#        [0.17074473],
#        [0.22380124],
#        [0.55123425],
#        [0.4307294 ],
#        [0.97811023],
#        [0.90922264],
#        [0.17495924],
#        [0.40007631]])

# %%
ibm.pars.Q
# Out:
# array([[0.25074185, 0.52072799, 0.4959445 ],
#        [0.52072799, 1.44608665, 0.96787349],
#        [0.4959445 , 0.96787349, 1.0173576 ]])

# %%
import numpy as np
from numpy.random import random as rnd 
import pandas as pd
from numpy.linalg import inv
import math

class parameters:
    def __init__(self,n):
        self.mu = rnd((n,1))
        self.F = rnd((n,n))
        self.R = rnd((1,1))
        self.q = rnd((n,n))
        self.Q = self.q.T@self.q
        self.beta00 = rnd((n,1))
        self.p00 = rnd((n,n))
        self.P00 = self.p00.T@self.p00
        self.parnames = list(self.__dict__.keys())
        self.parnames.sort()
        self.do_not_pack = ['Q','P00']
    def pack(self):
        big_column = np.array([[]]).T
        for aname in self.parnames: 
            if aname in self.do_not_pack: continue
            matrix = getattr(ibm.pars,aname) 
            matrix = matrix.reshape((-1,1),order = "F") 
            big_column = np.concatenate((big_column,matrix),axis = 0)
        return big_column
    def unpack(self, big_column):
        position = 0
        for aname in self.parnames:
            if aname in self.do_not_pack: continue
            matrix = getattr(ibm.pars,aname) 
            nrow, ncol = matrix.shape
            new_position = position + nrow*ncol
            new_matrix = big_column[position : new_position]
            new_matrix = new_matrix.reshape((nrow, ncol), order = 'F')
            setattr(self, aname, new_matrix)
            position = new_position
        self.Q = self.q.T@self.q
        self.P00 = self.p00.T@self.p00
            
class data:
    def __init__(self,n):
        self.y = rnd((1,1))
        self.x = rnd((1,n))
        
class prediction:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.eta = rnd((1,1))
        self.f = rnd((1,1))
        
class updating:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.K = rnd((n,1))
        
class a_period:
    def __init__(self,t,model):
        self.t = t
        self.mymodel = model
        n = self.mymodel.n
        self.data = data(n)
        self.prd = prediction(n)
        self.upd = updating(n)
    def predict(self):
        par = self.mymodel.pars
        mu = par.mu
        F = par.F
        if self.t == 0: 
            b = par.beta00
            P = par.P00
        else:
            previous_period = self.mymodel.sample[self.t-1]
            b = previous_period.upd.beta
            P = previous_period.upd.P
        self.prd.beta = mu + F @ b
        self.prd.P = (F @ P) @ F.T + par.Q
        x = self.data.x
        eta = self.data.y - x @ self.prd.beta
        f = (x @ self.prd.P) @ x.T + par.R
        self.prd.eta = eta
        self.prd.f = f
        self.ll = float( math.log(2 * math.pi * f) + (eta.T @ inv(f)) @ eta )
        
    def update(self):
        P = self.prd.P
        x = self.data.x
        K = (P @ x.T) @ ii(self.prd.f)
        self.upd.K = K
        self.upd.beta = self.prd.beta + K @ self.prd.eta
        self.upd.P = P - (K @ x) @ P
            
class the_model:
    def __init__(self,datafile):
        self.datafile = datafile
        df = pd.read_csv(datafile)
        T,n = df.shape
        n = n - 1
        self.n = n
        self.T = T
        self.pars = parameters(n)
        self.sample = []
        for t in range(T): 
            new_period = a_period(t,self)
            new_period.data.y = np.array([[ df.iloc[t,0] ]])
            new_period.data.x = df.iloc[t,1:].values.reshape((1,n))
            self.sample.append(new_period)
    def run(self):
        self.ll = 0
        for t in range(self.T):
            period_t = self.sample[t]
            period_t.predict()
            period_t.update()
            self.ll = self.ll + period_t.ll
        self.ll = -0.5 * self.ll

# %%
ibm = the_model("IBM.csv")

# %%
verylong = ibm.pars.pack()

# %%
verylong
# Out:
# array([[0.32767097],
#        [0.79334154],
#        [0.29986159],
#        [0.27160096],
#        [0.75801044],
#        [0.31307124],
#        [0.97263743],
#        [0.57881373],
#        [0.39754809],
#        [0.25472049],
#        [0.62884929],
#        [0.34376763],
#        [0.96838304],
#        [0.79968369],
#        [0.035909  ],
#        [0.14406206],
#        [0.81950696],
#        [0.64691175],
#        [0.23386313],
#        [0.27244569],
#        [0.56368905],
#        [0.28537286],
#        [0.13650523],
#        [0.85890557],
#        [0.25998264],
#        [0.11067723],
#        [0.18537215],
#        [0.78338975],
#        [0.67567166],
#        [0.9141737 ],
#        [0.79826711],
#        [0.25963651],
#        [0.14361388],
#        [0.81798706]])

# %%
from copy import deepcopy as dc

# %%
original_parameters = dc(ibm.pars)

# %%
original_parameters.__dict__
# Out:
# {'mu': array([[0.79968369],
#         [0.035909  ],
#         [0.14406206]]),
#  'F': array([[0.32767097, 0.27160096, 0.97263743],
#         [0.79334154, 0.75801044, 0.57881373],
#         [0.29986159, 0.31307124, 0.39754809]]),
#  'R': array([[0.25472049]]),
#  'q': array([[0.11067723, 0.67567166, 0.25963651],
#         [0.18537215, 0.9141737 , 0.14361388],
#         [0.78338975, 0.79826711, 0.81798706]]),
#  'Q': array([[0.66031178, 0.86959808, 0.69616054],
#         [0.86959808, 1.92947613, 0.95968923],
#         [0.69616054, 0.95968923, 0.75713889]]),
#  'beta00': array([[0.62884929],
#         [0.34376763],
#         [0.96838304]]),
#  'p00': array([[0.81950696, 0.27244569, 0.13650523],
#         [0.64691175, 0.56368905, 0.85890557],
#         [0.23386313, 0.28537286, 0.25998264]]),
#  'P00': array([[1.14477844, 0.65466641, 0.72830345],
#         [0.65466641, 0.47340968, 0.59553792],
#         [0.72830345, 0.59553792, 0.82394343]]),
#  'parnames': ['F', 'P00', 'Q', 'R', 'beta00', 'mu', 'p00', 'q'],
#  'do_not_pack': ['Q', 'P00']}

# %%
new_parameters = parameters(3)

# %%
original_parameters.F
# Out:
# array([[0.32767097, 0.27160096, 0.97263743],
#        [0.79334154, 0.75801044, 0.57881373],
#        [0.29986159, 0.31307124, 0.39754809]])

# %%
new_parameters.F
# Out:
# array([[0.53681764, 0.39849255, 0.40210815],
#        [0.41594359, 0.63826622, 0.34647715],
#        [0.55282848, 0.03367481, 0.52700789]])

# %%
original_parameters.Q
# Out:
# array([[0.66031178, 0.86959808, 0.69616054],
#        [0.86959808, 1.92947613, 0.95968923],
#        [0.69616054, 0.95968923, 0.75713889]])

# %%
new_parameters.Q
# Out:
# array([[0.67152873, 0.3852717 , 0.46105515],
#        [0.3852717 , 0.90460712, 0.76896432],
#        [0.46105515, 0.76896432, 0.73049711]])

# %%
new_parameters.unpack(verylong)

# %%
original_parameters.F
# Out:
# array([[0.32767097, 0.27160096, 0.97263743],
#        [0.79334154, 0.75801044, 0.57881373],
#        [0.29986159, 0.31307124, 0.39754809]])

# %%
new_parameters.F
# Out:
# array([[0.32767097, 0.27160096, 0.97263743],
#        [0.79334154, 0.75801044, 0.57881373],
#        [0.29986159, 0.31307124, 0.39754809]])

# %%
original_parameters.Q
# Out:
# array([[0.66031178, 0.86959808, 0.69616054],
#        [0.86959808, 1.92947613, 0.95968923],
#        [0.69616054, 0.95968923, 0.75713889]])

# %%
new_parameters.Q
# Out:
# array([[0.66031178, 0.86959808, 0.69616054],
#        [0.86959808, 1.92947613, 0.95968923],
#        [0.69616054, 0.95968923, 0.75713889]])

# %%
original_parameters.Q == new_parameters.Q
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]])

# %%
for aname in original_parameters.parnames:
    print ('+++++ '+aname+' +++++')
    print (getattr(original_parameters, aname) == getattr(new_parameters, aname))
# Out:
# +++++ F +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ P00 +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ Q +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ R +++++
# [[ True]]
# +++++ beta00 +++++
# [[ True]
#  [ True]
#  [ True]]
# +++++ mu +++++
# [[ True]
#  [ True]
#  [ True]]
# +++++ p00 +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ q +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]

# %%
original_parameters = dc(ibm.pars)
new_parameters = parameters(3)

# %%
for aname in original_parameters.parnames:
    print ('+++++ '+aname+' +++++')
    print (getattr(original_parameters, aname) == getattr(new_parameters, aname))
# Out:
# +++++ F +++++
# [[False False False]
#  [False False False]
#  [False False False]]
# +++++ P00 +++++
# [[False False False]
#  [False False False]
#  [False False False]]
# +++++ Q +++++
# [[False False False]
#  [False False False]
#  [False False False]]
# +++++ R +++++
# [[False]]
# +++++ beta00 +++++
# [[False]
#  [False]
#  [False]]
# +++++ mu +++++
# [[False]
#  [False]
#  [False]]
# +++++ p00 +++++
# [[False False False]
#  [False False False]
#  [False False False]]
# +++++ q +++++
# [[False False False]
#  [False False False]
#  [False False False]]

# %%
new_parameters.unpack(verylong)

# %%
for aname in original_parameters.parnames:
    print ('+++++ '+aname+' +++++')
    print (getattr(original_parameters, aname) == getattr(new_parameters, aname))
# Out:
# +++++ F +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ P00 +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ Q +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ R +++++
# [[ True]]
# +++++ beta00 +++++
# [[ True]
#  [ True]
#  [ True]]
# +++++ mu +++++
# [[ True]
#  [ True]
#  [ True]]
# +++++ p00 +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]
# +++++ q +++++
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]

# %% [markdown]
# We should NOT forget that the variance of errors, R, can not be negative! So, we need to make sure it is not negative.

# %%
import numpy as np
from numpy.random import random as rnd 
import pandas as pd
from numpy.linalg import inv
import math

class parameters:
    def __init__(self,n):
        self.mu = rnd((n,1))
        self.F = rnd((n,n))
        self.r = rnd((1,1))
        self.R = self.r.T@self.r
        self.q = rnd((n,n))
        self.Q = self.q.T@self.q
        self.beta00 = rnd((n,1))
        self.p00 = rnd((n,n))
        self.P00 = self.p00.T@self.p00
        self.parnames = list(self.__dict__.keys())
        self.parnames.sort()
        self.do_not_pack = ['R','Q','P00']
    def pack(self):
        big_column = np.array([[]]).T
        for aname in self.parnames: 
            if aname in self.do_not_pack: continue
            matrix = getattr(ibm.pars,aname) 
            matrix = matrix.reshape((-1,1),order = "F") 
            big_column = np.concatenate((big_column,matrix),axis = 0)
        return big_column
    def unpack(self, big_column):
        position = 0
        for aname in self.parnames:
            if aname in self.do_not_pack: continue
            matrix = getattr(ibm.pars,aname) 
            nrow, ncol = matrix.shape
            new_position = position + nrow*ncol
            new_matrix = big_column[position : new_position]
            new_matrix = new_matrix.reshape((nrow, ncol), order = 'F')
            setattr(self, aname, new_matrix)
            position = new_position
        self.R = self.r.T@self.r
        self.Q = self.q.T@self.q
        self.P00 = self.p00.T@self.p00
            
class data:
    def __init__(self,n):
        self.y = rnd((1,1))
        self.x = rnd((1,n))
        
class prediction:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.eta = rnd((1,1))
        self.f = rnd((1,1))
        
class updating:
    def __init__(self,n):
        self.beta = rnd((n,1))
        self.P = rnd((n,n))
        self.K = rnd((n,1))
        
class a_period:
    def __init__(self,t,model):
        self.t = t
        self.mymodel = model
        n = self.mymodel.n
        self.data = data(n)
        self.prd = prediction(n)
        self.upd = updating(n)
    def predict(self):
        par = self.mymodel.pars
        mu = par.mu
        F = par.F
        if self.t == 0: 
            b = par.beta00
            P = par.P00
        else:
            previous_period = self.mymodel.sample[self.t-1]
            b = previous_period.upd.beta
            P = previous_period.upd.P
        self.prd.beta = mu + F @ b
        self.prd.P = (F @ P) @ F.T + par.Q
        x = self.data.x
        eta = self.data.y - x @ self.prd.beta
        f = (x @ self.prd.P) @ x.T + par.R
        self.prd.eta = eta
        self.prd.f = f
        self.ll = float( math.log(2 * math.pi * f) + (eta.T @ inv(f)) @ eta )
        
    def update(self):
        P = self.prd.P
        x = self.data.x
        K = (P @ x.T) @ ii(self.prd.f)
        self.upd.K = K
        self.upd.beta = self.prd.beta + K @ self.prd.eta
        self.upd.P = P - (K @ x) @ P
            
class the_model:
    def __init__(self,datafile):
        self.datafile = datafile
        df = pd.read_csv(datafile)
        T,n = df.shape
        n = n - 1
        self.n = n
        self.T = T
        self.pars = parameters(n)
        self.sample = []
        for t in range(T): 
            new_period = a_period(t,self)
            new_period.data.y = np.array([[ df.iloc[t,0] ]])
            new_period.data.x = df.iloc[t,1:].values.reshape((1,n))
            self.sample.append(new_period)
    def run(self):
        self.ll = 0
        for t in range(self.T):
            period_t = self.sample[t]
            period_t.predict()
            period_t.update()
            self.ll = self.ll + period_t.ll
        self.ll = -0.5 * self.ll

# %% [markdown]
# <h3>Scratchwork:</h3>

# %%
ibm.pars.mu
# Out:
# array([[0.87152552],
#        [0.08092436],
#        [0.9425948 ]])

# %%
ibm.pars.F
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
F = ibm.pars.F

# %%
F
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
F.shape
# Out:
# (3, 3)

# %%
F.reshape((9,1))
# Out:
# array([[0.96439256],
#        [0.73159145],
#        [0.16776893],
#        [0.55231926],
#        [0.39272163],
#        [0.92201489],
#        [0.9891472 ],
#        [0.24715212],
#        [0.26765849]])

# %%
F.reshape((1,9))
# Out:
# array([[0.96439256, 0.73159145, 0.16776893, 0.55231926, 0.39272163,
#         0.92201489, 0.9891472 , 0.24715212, 0.26765849]])

# %%
F.reshape((1,-1))
# Out:
# array([[0.96439256, 0.73159145, 0.16776893, 0.55231926, 0.39272163,
#         0.92201489, 0.9891472 , 0.24715212, 0.26765849]])

# %%
F.reshape((-1,9))
# Out:
# array([[0.96439256, 0.73159145, 0.16776893, 0.55231926, 0.39272163,
#         0.92201489, 0.9891472 , 0.24715212, 0.26765849]])

# %%
F.reshape((-1,1))
# Out:
# array([[0.96439256],
#        [0.73159145],
#        [0.16776893],
#        [0.55231926],
#        [0.39272163],
#        [0.92201489],
#        [0.9891472 ],
#        [0.24715212],
#        [0.26765849]])

# %%
F
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
Q = ibm.pars.Q

# %%
Q
# Out:
# array([[0.35974823, 0.26570366, 0.15585106],
#        [0.26570366, 0.3623482 , 0.12209725],
#        [0.15585106, 0.12209725, 0.07960544]])

# %%
Q.reshape((-1,1))
# Out:
# array([[0.35974823],
#        [0.26570366],
#        [0.15585106],
#        [0.26570366],
#        [0.3623482 ],
#        [0.12209725],
#        [0.15585106],
#        [0.12209725],
#        [0.07960544]])

# %%
Q
# Out:
# array([[0.35974823, 0.26570366, 0.15585106],
#        [0.26570366, 0.3623482 , 0.12209725],
#        [0.15585106, 0.12209725, 0.07960544]])

# %%
Q.reshape((-1,1), order='F') # that is, the Fortran order.
# Out:
# array([[0.35974823],
#        [0.26570366],
#        [0.15585106],
#        [0.26570366],
#        [0.3623482 ],
#        [0.12209725],
#        [0.15585106],
#        [0.12209725],
#        [0.07960544]])

# %%
mu = ibm.pars.mu

# %%
mu
# Out:
# array([[0.87152552],
#        [0.08092436],
#        [0.9425948 ]])

# %%
cQ = Q.reshape((-1,1), order='F')

# %%
cQ
# Out:
# array([[0.35974823],
#        [0.26570366],
#        [0.15585106],
#        [0.26570366],
#        [0.3623482 ],
#        [0.12209725],
#        [0.15585106],
#        [0.12209725],
#        [0.07960544]])

# %%
np.concatenate((mu,cQ),axis = 0)
# Out:
# array([[0.87152552],
#        [0.08092436],
#        [0.9425948 ],
#        [0.35974823],
#        [0.26570366],
#        [0.15585106],
#        [0.26570366],
#        [0.3623482 ],
#        [0.12209725],
#        [0.15585106],
#        [0.12209725],
#        [0.07960544]])

# %%
ibm.pars.__dict__
# Out:
# {'mu': array([[0.87152552],
#         [0.08092436],
#         [0.9425948 ]]),
#  'F': array([[0.96439256, 0.73159145, 0.16776893],
#         [0.55231926, 0.39272163, 0.92201489],
#         [0.9891472 , 0.24715212, 0.26765849]]),
#  'R': array([[0.74705871]]),
#  'q': array([[0.28648225, 0.53967305, 0.09969657],
#         [0.27276258, 0.2488123 , 0.21605008],
#         [0.4508622 , 0.09588347, 0.15161924]]),
#  'Q': array([[0.35974823, 0.26570366, 0.15585106],
#         [0.26570366, 0.3623482 , 0.12209725],
#         [0.15585106, 0.12209725, 0.07960544]]),
#  'beta00': array([[0.54867541],
#         [0.21814241],
#         [0.30831502]]),
#  'p00': array([[0.83396823, 0.20888618, 0.9943604 ],
#         [0.35327771, 0.21622132, 0.58249905],
#         [0.43421853, 0.19457631, 0.1212151 ]]),
#  'P00': array([[1.00885389, 0.33507925, 1.08768276],
#         [0.33507925, 0.12824504, 0.35724245],
#         [1.08768276, 0.35724245, 1.34275086]])}

# %%
ibm.__dict__
# Out:
# {'datafile': 'IBM.csv',
#  'n': 3,
#  'T': 405,
#  'pars': <__main__.parameters at 0x7f3edf9b5e90>,
#  'sample': [<__main__.a_period at 0x7f3edf9b5d10>,
#   <__main__.a_period at 0x7f3edf9b5750>,
#   <__main__.a_period at 0x7f3edf9b5650>,
#   <__main__.a_period at 0x7f3f08235dd0>,
#   <__main__.a_period at 0x7f3f08235c90>,
#   <__main__.a_period at 0x7f3edfab1790>,
#   <__main__.a_period at 0x7f3edfab1dd0>,
#   <__main__.a_period at 0x7f3edfab1b50>,
#   <__main__.a_period at 0x7f3edfab1510>,
#   <__main__.a_period at 0x7f3edfab1b90>,
#   <__main__.a_period at 0x7f3edfa03810>,
#   <__main__.a_period at 0x7f3edfa03790>,
#   <__main__.a_period at 0x7f3edfa035d0>,
#   <__main__.a_period at 0x7f3edfa039d0>,
#   <__main__.a_period at 0x7f3edfa03510>,
#   <__main__.a_period at 0x7f3edfa032d0>,
#   <__main__.a_period at 0x7f3edf9d3050>,
#   <__main__.a_period at 0x7f3edf9d3350>,
#   <__main__.a_period at 0x7f3edf9d3450>,
#   <__main__.a_period at 0x7f3edf9d3550>,
#   <__main__.a_period at 0x7f3edf9d3650>,
#   <__main__.a_period at 0x7f3edf9d3750>,
#   <__main__.a_period at 0x7f3edf9d3850>,
#   <__main__.a_period at 0x7f3edf9d3950>,
#   <__main__.a_period at 0x7f3edf9d3a50>,
#   <__main__.a_period at 0x7f3edf9d3b50>,
#   <__main__.a_period at 0x7f3edf9d3c50>,
#   <__main__.a_period at 0x7f3edf9d3d50>,
#   <__main__.a_period at 0x7f3edf9d3e50>,
#   <__main__.a_period at 0x7f3edf9d3e90>,
#   <__main__.a_period at 0x7f3edf9ba090>,
#   <__main__.a_period at 0x7f3edf9ba190>,
#   <__main__.a_period at 0x7f3edf9ba290>,
#   <__main__.a_period at 0x7f3edf9ba390>,
#   <__main__.a_period at 0x7f3edf9ba490>,
#   <__main__.a_period at 0x7f3edf9ba590>,
#   <__main__.a_period at 0x7f3edf9ba690>,
#   <__main__.a_period at 0x7f3edf9ba790>,
#   <__main__.a_period at 0x7f3edf9ba890>,
#   <__main__.a_period at 0x7f3edf9ba990>,
#   <__main__.a_period at 0x7f3edf9baa90>,
#   <__main__.a_period at 0x7f3edf9bab90>,
#   <__main__.a_period at 0x7f3edf9bac90>,
#   <__main__.a_period at 0x7f3edf9bad90>,
#   <__main__.a_period at 0x7f3edf9bae90>,
#   <__main__.a_period at 0x7f3edf9bafd0>,
#   <__main__.a_period at 0x7f3edf9c10d0>,
#   <__main__.a_period at 0x7f3edf9c15d0>,
#   <__main__.a_period at 0x7f3edf9c14d0>,
#   <__main__.a_period at 0x7f3edf9c16d0>,
#   <__main__.a_period at 0x7f3edf9c1710>,
#   <__main__.a_period at 0x7f3edf9c1910>,
#   <__main__.a_period at 0x7f3edf9c12d0>,
#   <__main__.a_period at 0x7f3edf9c13d0>,
#   <__main__.a_period at 0x7f3edf9c1150>,
#   <__main__.a_period at 0x7f3edf9c1ad0>,
#   <__main__.a_period at 0x7f3edf9c1990>,
#   <__main__.a_period at 0x7f3edf9c1c90>,
#   <__main__.a_period at 0x7f3edf9c1dd0>,
#   <__main__.a_period at 0x7f3edf9c1d50>,
#   <__main__.a_period at 0x7f3edf9c1bd0>,
#   <__main__.a_period at 0x7f3edf9c1f10>,
#   <__main__.a_period at 0x7f3edf9c7090>,
#   <__main__.a_period at 0x7f3edf9c7250>,
#   <__main__.a_period at 0x7f3edf9c7310>,
#   <__main__.a_period at 0x7f3edf9c7410>,
#   <__main__.a_period at 0x7f3edf9c7510>,
#   <__main__.a_period at 0x7f3edf9c7550>,
#   <__main__.a_period at 0x7f3edf9c76d0>,
#   <__main__.a_period at 0x7f3edf9c7950>,
#   <__main__.a_period at 0x7f3edf9c7910>,
#   <__main__.a_period at 0x7f3edf9c7c50>,
#   <__main__.a_period at 0x7f3edf9c7dd0>,
#   <__main__.a_period at 0x7f3edf9c7b90>,
#   <__main__.a_period at 0x7f3edf9c7b10>,
#   <__main__.a_period at 0x7f3edfa03ad0>,
#   <__main__.a_period at 0x7f3edfa03750>,
#   <__main__.a_period at 0x7f3edfab1c90>,
#   <__main__.a_period at 0x7f3f081db150>,
#   <__main__.a_period at 0x7f3edf9c7e50>,
#   <__main__.a_period at 0x7f3edf9c77d0>,
#   <__main__.a_period at 0x7f3edf9d5110>,
#   <__main__.a_period at 0x7f3edf9d5210>,
#   <__main__.a_period at 0x7f3edf9d5310>,
#   <__main__.a_period at 0x7f3edf9d5410>,
#   <__main__.a_period at 0x7f3edf9d5510>,
#   <__main__.a_period at 0x7f3edf9d5610>,
#   <__main__.a_period at 0x7f3edf9d5710>,
#   <__main__.a_period at 0x7f3edf9d5810>,
#   <__main__.a_period at 0x7f3edf9d5910>,
#   <__main__.a_period at 0x7f3edf9d5a10>,
#   <__main__.a_period at 0x7f3edf9d5b10>,
#   <__main__.a_period at 0x7f3edf9d5c10>,
#   <__main__.a_period at 0x7f3edf9d5d10>,
#   <__main__.a_period at 0x7f3edf9d5e10>,
#   <__main__.a_period at 0x7f3edf9d5e50>,
#   <__main__.a_period at 0x7f3edf95c050>,
#   <__main__.a_period at 0x7f3edf95c150>,
#   <__main__.a_period at 0x7f3edf95c250>,
#   <__main__.a_period at 0x7f3edf95c350>,
#   <__main__.a_period at 0x7f3edf95c450>,
#   <__main__.a_period at 0x7f3edf95c550>,
#   <__main__.a_period at 0x7f3edf95c650>,
#   <__main__.a_period at 0x7f3edf95c750>,
#   <__main__.a_period at 0x7f3edf95c850>,
#   <__main__.a_period at 0x7f3edf95c950>,
#   <__main__.a_period at 0x7f3edf95ca50>,
#   <__main__.a_period at 0x7f3edf95cb50>,
#   <__main__.a_period at 0x7f3edf95cc50>,
#   <__main__.a_period at 0x7f3edf95cd50>,
#   <__main__.a_period at 0x7f3edf95ce50>,
#   <__main__.a_period at 0x7f3edf95ce90>,
#   <__main__.a_period at 0x7f3edf961090>,
#   <__main__.a_period at 0x7f3edf961190>,
#   <__main__.a_period at 0x7f3edf961290>,
#   <__main__.a_period at 0x7f3edf961390>,
#   <__main__.a_period at 0x7f3edf961490>,
#   <__main__.a_period at 0x7f3edf961590>,
#   <__main__.a_period at 0x7f3edf961690>,
#   <__main__.a_period at 0x7f3edf961790>,
#   <__main__.a_period at 0x7f3edf961890>,
#   <__main__.a_period at 0x7f3edf961990>,
#   <__main__.a_period at 0x7f3edf961a90>,
#   <__main__.a_period at 0x7f3edf961b90>,
#   <__main__.a_period at 0x7f3edf961c90>,
#   <__main__.a_period at 0x7f3edf961d90>,
#   <__main__.a_period at 0x7f3edf961e90>,
#   <__main__.a_period at 0x7f3edf961fd0>,
#   <__main__.a_period at 0x7f3edf9660d0>,
#   <__main__.a_period at 0x7f3edf9661d0>,
#   <__main__.a_period at 0x7f3edf9662d0>,
#   <__main__.a_period at 0x7f3edf9663d0>,
#   <__main__.a_period at 0x7f3edf9664d0>,
#   <__main__.a_period at 0x7f3edf9665d0>,
#   <__main__.a_period at 0x7f3edf9666d0>,
#   <__main__.a_period at 0x7f3edf9667d0>,
#   <__main__.a_period at 0x7f3edf9668d0>,
#   <__main__.a_period at 0x7f3edf9669d0>,
#   <__main__.a_period at 0x7f3edf966ad0>,
#   <__main__.a_period at 0x7f3edf966bd0>,
#   <__main__.a_period at 0x7f3edf966cd0>,
#   <__main__.a_period at 0x7f3edf966dd0>,
#   <__main__.a_period at 0x7f3edf966e10>,
#   <__main__.a_period at 0x7f3edf966fd0>,
#   <__main__.a_period at 0x7f3edf96c110>,
#   <__main__.a_period at 0x7f3edf96c210>,
#   <__main__.a_period at 0x7f3edf96c310>,
#   <__main__.a_period at 0x7f3edf96c410>,
#   <__main__.a_period at 0x7f3edf96c510>,
#   <__main__.a_period at 0x7f3edf96c610>,
#   <__main__.a_period at 0x7f3edf96c710>,
#   <__main__.a_period at 0x7f3edf96c810>,
#   <__main__.a_period at 0x7f3edf96c910>,
#   <__main__.a_period at 0x7f3edf96ca10>,
#   <__main__.a_period at 0x7f3edf96cb10>,
#   <__main__.a_period at 0x7f3edf96cc10>,
#   <__main__.a_period at 0x7f3edf96cd10>,
#   <__main__.a_period at 0x7f3edf96ce10>,
#   <__main__.a_period at 0x7f3edf96ce50>,
#   <__main__.a_period at 0x7f3edf972050>,
#   <__main__.a_period at 0x7f3edf972150>,
#   <__main__.a_period at 0x7f3edf972250>,
#   <__main__.a_period at 0x7f3edf972350>,
#   <__main__.a_period at 0x7f3edf972450>,
#   <__main__.a_period at 0x7f3edf972550>,
#   <__main__.a_period at 0x7f3edf972650>,
#   <__main__.a_period at 0x7f3edf972750>,
#   <__main__.a_period at 0x7f3edf972850>,
#   <__main__.a_period at 0x7f3edf972950>,
#   <__main__.a_period at 0x7f3edf972a50>,
#   <__main__.a_period at 0x7f3edf972b50>,
#   <__main__.a_period at 0x7f3edf972c50>,
#   <__main__.a_period at 0x7f3edf972d50>,
#   <__main__.a_period at 0x7f3edf972e50>,
#   <__main__.a_period at 0x7f3edf972e90>,
#   <__main__.a_period at 0x7f3edf977090>,
#   <__main__.a_period at 0x7f3edf977190>,
#   <__main__.a_period at 0x7f3edf977290>,
#   <__main__.a_period at 0x7f3edf977390>,
#   <__main__.a_period at 0x7f3edf977490>,
#   <__main__.a_period at 0x7f3edf977590>,
#   <__main__.a_period at 0x7f3edf977690>,
#   <__main__.a_period at 0x7f3edf977790>,
#   <__main__.a_period at 0x7f3edf977890>,
#   <__main__.a_period at 0x7f3edf977990>,
#   <__main__.a_period at 0x7f3edf977a90>,
#   <__main__.a_period at 0x7f3edf977b90>,
#   <__main__.a_period at 0x7f3edf977c90>,
#   <__main__.a_period at 0x7f3edf977d90>,
#   <__main__.a_period at 0x7f3edf977e90>,
#   <__main__.a_period at 0x7f3edf977fd0>,
#   <__main__.a_period at 0x7f3edf97d0d0>,
#   <__main__.a_period at 0x7f3edf97d1d0>,
#   <__main__.a_period at 0x7f3edf97d2d0>,
#   <__main__.a_period at 0x7f3edf97d3d0>,
#   <__main__.a_period at 0x7f3edf97d4d0>,
#   <__main__.a_period at 0x7f3edf97d5d0>,
#   <__main__.a_period at 0x7f3edf97d6d0>,
#   <__main__.a_period at 0x7f3edf97d7d0>,
#   <__main__.a_period at 0x7f3edf97d8d0>,
#   <__main__.a_period at 0x7f3edf97d9d0>,
#   <__main__.a_period at 0x7f3edf97dad0>,
#   <__main__.a_period at 0x7f3edf97dbd0>,
#   <__main__.a_period at 0x7f3edf97dcd0>,
#   <__main__.a_period at 0x7f3edf97ddd0>,
#   <__main__.a_period at 0x7f3edf97de10>,
#   <__main__.a_period at 0x7f3edf97dfd0>,
#   <__main__.a_period at 0x7f3edf983110>,
#   <__main__.a_period at 0x7f3edf983210>,
#   <__main__.a_period at 0x7f3edf983310>,
#   <__main__.a_period at 0x7f3edf983410>,
#   <__main__.a_period at 0x7f3edf983510>,
#   <__main__.a_period at 0x7f3edf983610>,
#   <__main__.a_period at 0x7f3edf983710>,
#   <__main__.a_period at 0x7f3edf983810>,
#   <__main__.a_period at 0x7f3edf983910>,
#   <__main__.a_period at 0x7f3edf983a10>,
#   <__main__.a_period at 0x7f3edf983b10>,
#   <__main__.a_period at 0x7f3edf983c10>,
#   <__main__.a_period at 0x7f3edf983d10>,
#   <__main__.a_period at 0x7f3edf983e10>,
#   <__main__.a_period at 0x7f3edf983e50>,
#   <__main__.a_period at 0x7f3edf989050>,
#   <__main__.a_period at 0x7f3edf989150>,
#   <__main__.a_period at 0x7f3edf989250>,
#   <__main__.a_period at 0x7f3edf989350>,
#   <__main__.a_period at 0x7f3edf989450>,
#   <__main__.a_period at 0x7f3edf989550>,
#   <__main__.a_period at 0x7f3edf989650>,
#   <__main__.a_period at 0x7f3edf989750>,
#   <__main__.a_period at 0x7f3edf989850>,
#   <__main__.a_period at 0x7f3edf989950>,
#   <__main__.a_period at 0x7f3edf989a50>,
#   <__main__.a_period at 0x7f3edf989b50>,
#   <__main__.a_period at 0x7f3edf989c50>,
#   <__main__.a_period at 0x7f3edf989d50>,
#   <__main__.a_period at 0x7f3edf989e50>,
#   <__main__.a_period at 0x7f3edf989e90>,
#   <__main__.a_period at 0x7f3edf98f090>,
#   <__main__.a_period at 0x7f3edf98f190>,
#   <__main__.a_period at 0x7f3edf98f290>,
#   <__main__.a_period at 0x7f3edf98f390>,
#   <__main__.a_period at 0x7f3edf98f490>,
#   <__main__.a_period at 0x7f3edf98f590>,
#   <__main__.a_period at 0x7f3edf98f690>,
#   <__main__.a_period at 0x7f3edf98f790>,
#   <__main__.a_period at 0x7f3edf98f890>,
#   <__main__.a_period at 0x7f3edf98f990>,
#   <__main__.a_period at 0x7f3edf98fa90>,
#   <__main__.a_period at 0x7f3edf98fb90>,
#   <__main__.a_period at 0x7f3edf98fc90>,
#   <__main__.a_period at 0x7f3edf98fd90>,
#   <__main__.a_period at 0x7f3edf98fe90>,
#   <__main__.a_period at 0x7f3edf98ffd0>,
#   <__main__.a_period at 0x7f3edf9950d0>,
#   <__main__.a_period at 0x7f3edf9951d0>,
#   <__main__.a_period at 0x7f3edf9952d0>,
#   <__main__.a_period at 0x7f3edf9953d0>,
#   <__main__.a_period at 0x7f3edf9954d0>,
#   <__main__.a_period at 0x7f3edf9955d0>,
#   <__main__.a_period at 0x7f3edf9956d0>,
#   <__main__.a_period at 0x7f3edf9957d0>,
#   <__main__.a_period at 0x7f3edf9958d0>,
#   <__main__.a_period at 0x7f3edf9959d0>,
#   <__main__.a_period at 0x7f3edf995ad0>,
#   <__main__.a_period at 0x7f3edf995bd0>,
#   <__main__.a_period at 0x7f3edf995cd0>,
#   <__main__.a_period at 0x7f3edf995dd0>,
#   <__main__.a_period at 0x7f3edf995e10>,
#   <__main__.a_period at 0x7f3edf995fd0>,
#   <__main__.a_period at 0x7f3edf91b110>,
#   <__main__.a_period at 0x7f3edf91b210>,
#   <__main__.a_period at 0x7f3edf91b310>,
#   <__main__.a_period at 0x7f3edf91b410>,
#   <__main__.a_period at 0x7f3edf91b510>,
#   <__main__.a_period at 0x7f3edf91b610>,
#   <__main__.a_period at 0x7f3edf91b710>,
#   <__main__.a_period at 0x7f3edf91b810>,
#   <__main__.a_period at 0x7f3edf91b910>,
#   <__main__.a_period at 0x7f3edf91ba10>,
#   <__main__.a_period at 0x7f3edf91bb10>,
#   <__main__.a_period at 0x7f3edf91bc10>,
#   <__main__.a_period at 0x7f3edf91bd10>,
#   <__main__.a_period at 0x7f3edf91be10>,
#   <__main__.a_period at 0x7f3edf91be50>,
#   <__main__.a_period at 0x7f3edf921050>,
#   <__main__.a_period at 0x7f3edf921150>,
#   <__main__.a_period at 0x7f3edf921250>,
#   <__main__.a_period at 0x7f3edf921350>,
#   <__main__.a_period at 0x7f3edf921450>,
#   <__main__.a_period at 0x7f3edf921550>,
#   <__main__.a_period at 0x7f3edf921650>,
#   <__main__.a_period at 0x7f3edf921750>,
#   <__main__.a_period at 0x7f3edf921850>,
#   <__main__.a_period at 0x7f3edf921950>,
#   <__main__.a_period at 0x7f3edf921a50>,
#   <__main__.a_period at 0x7f3edf921b50>,
#   <__main__.a_period at 0x7f3edf921c50>,
#   <__main__.a_period at 0x7f3edf921d50>,
#   <__main__.a_period at 0x7f3edf921e50>,
#   <__main__.a_period at 0x7f3edf921e90>,
#   <__main__.a_period at 0x7f3edf926090>,
#   <__main__.a_period at 0x7f3edf926190>,
#   <__main__.a_period at 0x7f3edf926290>,
#   <__main__.a_period at 0x7f3edf926390>,
#   <__main__.a_period at 0x7f3edf926490>,
#   <__main__.a_period at 0x7f3edf926590>,
#   <__main__.a_period at 0x7f3edf926690>,
#   <__main__.a_period at 0x7f3edf926790>,
#   <__main__.a_period at 0x7f3edf926890>,
#   <__main__.a_period at 0x7f3edf926990>,
#   <__main__.a_period at 0x7f3edf926a90>,
#   <__main__.a_period at 0x7f3edf926b90>,
#   <__main__.a_period at 0x7f3edf926c90>,
#   <__main__.a_period at 0x7f3edf926d90>,
#   <__main__.a_period at 0x7f3edf926e90>,
#   <__main__.a_period at 0x7f3edf926fd0>,
#   <__main__.a_period at 0x7f3edf92c0d0>,
#   <__main__.a_period at 0x7f3edf92c1d0>,
#   <__main__.a_period at 0x7f3edf92c2d0>,
#   <__main__.a_period at 0x7f3edf92c3d0>,
#   <__main__.a_period at 0x7f3edf92c4d0>,
#   <__main__.a_period at 0x7f3edf92c5d0>,
#   <__main__.a_period at 0x7f3edf92c6d0>,
#   <__main__.a_period at 0x7f3edf92c7d0>,
#   <__main__.a_period at 0x7f3edf92c8d0>,
#   <__main__.a_period at 0x7f3edf92c9d0>,
#   <__main__.a_period at 0x7f3edf92cad0>,
#   <__main__.a_period at 0x7f3edf92cbd0>,
#   <__main__.a_period at 0x7f3edf92ccd0>,
#   <__main__.a_period at 0x7f3edf92cdd0>,
#   <__main__.a_period at 0x7f3edf92ce10>,
#   <__main__.a_period at 0x7f3edf92cfd0>,
#   <__main__.a_period at 0x7f3edf932110>,
#   <__main__.a_period at 0x7f3edf932210>,
#   <__main__.a_period at 0x7f3edf932310>,
#   <__main__.a_period at 0x7f3edf932410>,
#   <__main__.a_period at 0x7f3edf932510>,
#   <__main__.a_period at 0x7f3edf932610>,
#   <__main__.a_period at 0x7f3edf932710>,
#   <__main__.a_period at 0x7f3edf932810>,
#   <__main__.a_period at 0x7f3edf932910>,
#   <__main__.a_period at 0x7f3edf932a10>,
#   <__main__.a_period at 0x7f3edf932b10>,
#   <__main__.a_period at 0x7f3edf932c10>,
#   <__main__.a_period at 0x7f3edf932d10>,
#   <__main__.a_period at 0x7f3edf932e10>,
#   <__main__.a_period at 0x7f3edf932e50>,
#   <__main__.a_period at 0x7f3edf939050>,
#   <__main__.a_period at 0x7f3edf939150>,
#   <__main__.a_period at 0x7f3edf939250>,
#   <__main__.a_period at 0x7f3edf939350>,
#   <__main__.a_period at 0x7f3edf939450>,
#   <__main__.a_period at 0x7f3edf939550>,
#   <__main__.a_period at 0x7f3edf939650>,
#   <__main__.a_period at 0x7f3edf939750>,
#   <__main__.a_period at 0x7f3edf939850>,
#   <__main__.a_period at 0x7f3edf939950>,
#   <__main__.a_period at 0x7f3edf939a50>,
#   <__main__.a_period at 0x7f3edf939b50>,
#   <__main__.a_period at 0x7f3edf939c50>,
#   <__main__.a_period at 0x7f3edf939d50>,
#   <__main__.a_period at 0x7f3edf939e50>,
#   <__main__.a_period at 0x7f3edf939e90>,
#   <__main__.a_period at 0x7f3edf93e090>,
#   <__main__.a_period at 0x7f3edf93e190>,
#   <__main__.a_period at 0x7f3edf93e290>,
#   <__main__.a_period at 0x7f3edf93e390>,
#   <__main__.a_period at 0x7f3edf93e490>,
#   <__main__.a_period at 0x7f3edf93e590>,
#   <__main__.a_period at 0x7f3edf93e690>,
#   <__main__.a_period at 0x7f3edf93e790>,
#   <__main__.a_period at 0x7f3edf93e890>,
#   <__main__.a_period at 0x7f3edf93e990>,
#   <__main__.a_period at 0x7f3edf93ea90>,
#   <__main__.a_period at 0x7f3edf93eb90>,
#   <__main__.a_period at 0x7f3edf93ec90>,
#   <__main__.a_period at 0x7f3edf93ed90>,
#   <__main__.a_period at 0x7f3edf93ee90>,
#   <__main__.a_period at 0x7f3edf93efd0>,
#   <__main__.a_period at 0x7f3edf9440d0>,
#   <__main__.a_period at 0x7f3edf9441d0>,
#   <__main__.a_period at 0x7f3edf9442d0>,
#   <__main__.a_period at 0x7f3edf9443d0>,
#   <__main__.a_period at 0x7f3edf9444d0>,
#   <__main__.a_period at 0x7f3edf9445d0>,
#   <__main__.a_period at 0x7f3edf9446d0>,
#   <__main__.a_period at 0x7f3edf9447d0>,
#   <__main__.a_period at 0x7f3edf9448d0>,
#   <__main__.a_period at 0x7f3edf9449d0>,
#   <__main__.a_period at 0x7f3edf944ad0>,
#   <__main__.a_period at 0x7f3edf944bd0>,
#   <__main__.a_period at 0x7f3edf944cd0>,
#   <__main__.a_period at 0x7f3edf944dd0>,
#   <__main__.a_period at 0x7f3edf944e10>,
#   <__main__.a_period at 0x7f3edf944fd0>,
#   <__main__.a_period at 0x7f3edf94b110>,
#   <__main__.a_period at 0x7f3edf94b210>,
#   <__main__.a_period at 0x7f3edf94b310>,
#   <__main__.a_period at 0x7f3edf94b410>,
#   <__main__.a_period at 0x7f3edf94b510>,
#   <__main__.a_period at 0x7f3edf94b610>,
#   <__main__.a_period at 0x7f3edf94b710>,
#   <__main__.a_period at 0x7f3edf94b810>,
#   <__main__.a_period at 0x7f3edf94b910>],
#  'll': -548.0804221525112}

# %%
ibm.pars.__dict__.keys()
# Out:
# dict_keys(['mu', 'F', 'R', 'q', 'Q', 'beta00', 'p00', 'P00'])

# %%
list(ibm.pars.__dict__.keys())
# Out:
# ['mu', 'F', 'R', 'q', 'Q', 'beta00', 'p00', 'P00']

# %%
parnames = list(ibm.pars.__dict__.keys())

# %%
parnames
# Out:
# ['mu', 'F', 'R', 'q', 'Q', 'beta00', 'p00', 'P00']

# %%
parnames.sort()

# %%
parnames
# Out:
# ['F', 'P00', 'Q', 'R', 'beta00', 'mu', 'p00', 'q']

# %%
parnames[0]
# Out:
# 'F'

# %%
parnames[1]
# Out:
# 'P00'

# %%
parameter_0 = parnames[0]

# %%
parameter_0
# Out:
# 'F'

# %%
ibm.pars.F
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
ibm.pars.parameter_0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-0dfe8c0eea11> in <module>
# ----> 1 ibm.pars.parameter_0
#
# AttributeError: 'parameters' object has no attribute 'parameter_0'

# %%
# The "Get Attribute function":
getattr(ibm.pars, 'F')
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
ibm.pars.F
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
getattr(ibm.pars, parameter_0)
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %% [markdown]
# That is, this is saying: "<em>Get attribute from <tt><font color="blue">ibm.pars</font></tt>, whose name is specified in the variable <tt><font color="blue">parameter_0</font></tt>.</em>"

# %% [markdown]
# We can also set an attribute vlue by using a similar function.

# %%
newF = 'This is a new value of F'

# %%
newF
# Out:
# 'This is a new value of F'

# %%
ibm.pars.F
# Out:
# array([[0.96439256, 0.73159145, 0.16776893],
#        [0.55231926, 0.39272163, 0.92201489],
#        [0.9891472 , 0.24715212, 0.26765849]])

# %%
setattr(ibm.pars, parameter_0, newF)

# %% [markdown]
# In the object by the name <font color="blue"><tt>ibm.pars</tt></font>, we set the attribute by the name <font color="blue"><tt>parameter_0</tt></font> to be equal to the new value <font color="blue"><tt>newF</tt></font>.

# %%
ibm.pars.F
# Out:
# 'This is a new value of F'

# %%
getattr(ibm.pars, parameter_0)
# Out:
# 'This is a new value of F'

# %%
parnames
# Out:
# ['F', 'P00', 'Q', 'R', 'beta00', 'mu', 'p00', 'q']

# %%
big_column = np.array([[]])

# %%
big_column
# Out:
# array([], shape=(1, 0), dtype=float64)

# %%
big_column.T
# Out:
# array([], shape=(0, 1), dtype=float64)

# %%
big_column = np.array([[]]).T

# %%
big_column
# Out:
# array([], shape=(0, 1), dtype=float64)

# %%
np.concatenate((big_column,mu),axis = 0)
# Out:
# array([[0.87152552],
#        [0.08092436],
#        [0.9425948 ]])

# %%
mu
# Out:
# array([[0.87152552],
#        [0.08092436],
#        [0.9425948 ]])

# %%
parnames
# Out:
# ['F', 'P00', 'Q', 'R', 'beta00', 'mu', 'p00', 'q']

# %%
for aname in parnames:
    print (aname)
# Out:
# F
# P00
# Q
# R
# beta00
# mu
# p00
# q

# %%
big_column = np.array([[]]).T # Set up an empty column.
for aname in parnames: # Loop over all parameter names.
    matrix = getattr(ibm.pars,aname) # Extract the value of the matrix by the name aname
    matrix = matrix.reshape((-1,1),order = "F") # Turn that matrix into a column.
    big_column = np.concatenate((big_column,matrix),axis = 0) # Concat it to the big_column.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-ca0c814bf5d9> in <module>
#       2 for aname in parnames: # Loop over all parameter names.
#       3     matrix = getattr(ibm.pars,aname) # Extract the value of the matrix by the name aname
# ----> 4     matrix = matrix.reshape((-1,1),order = "F") # Turn that matrix into a column.
#       5     big_column = np.concatenate((big_column,matrix),axis = 0) # Concat it to the big_column.
#
# AttributeError: 'str' object has no attribute 'reshape'

# %%
aname = 'F'

# %%
matrix = getattr(ibm.pars,aname)

# %%
matrix
# Out:
# 'This is a new value of F'

# %%
matrix.reshape((-1,1),order = "F")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-eacefd66b83d> in <module>
# ----> 1 matrix.reshape((-1,1),order = "F")
#
# AttributeError: 'str' object has no attribute 'reshape'

# %%
n = 3
ibm.pars.F = rnd((n,n))

# %%
big_column = np.array([[]]).T # Set up an empty column.
for aname in parnames: # Loop over all parameter names.
    matrix = getattr(ibm.pars,aname) # Extract the value of the matrix by the name aname
    matrix = matrix.reshape((-1,1),order = "F") # Turn that matrix into a column.
    big_column = np.concatenate((big_column,matrix),axis = 0) # Concat it to the big_column.

# %%
big_column
# Out:
# array([[0.52269651],
#        [0.27455729],
#        [0.50837047],
#        [0.90670022],
#        [0.88888001],
#        [0.37969602],
#        [0.87493473],
#        [0.55270639],
#        [0.31258573],
#        [1.00885389],
#        [0.33507925],
#        [1.08768276],
#        [0.33507925],
#        [0.12824504],
#        [0.35724245],
#        [1.08768276],
#        [0.35724245],
#        [1.34275086],
#        [0.35974823],
#        [0.26570366],
#        [0.15585106],
#        [0.26570366],
#        [0.3623482 ],
#        [0.12209725],
#        [0.15585106],
#        [0.12209725],
#        [0.07960544],
#        [0.74705871],
#        [0.54867541],
#        [0.21814241],
#        [0.30831502],
#        [0.87152552],
#        [0.08092436],
#        [0.9425948 ],
#        [0.83396823],
#        [0.35327771],
#        [0.43421853],
#        [0.20888618],
#        [0.21622132],
#        [0.19457631],
#        [0.9943604 ],
#        [0.58249905],
#        [0.1212151 ],
#        [0.28648225],
#        [0.27276258],
#        [0.4508622 ],
#        [0.53967305],
#        [0.2488123 ],
#        [0.09588347],
#        [0.09969657],
#        [0.21605008],
#        [0.15161924]])
